# %%
from genes import NodeGene, EdgeGene
from chromosome import Chromosome

# %%
C0 = Chromosome(
        id=0,
        nodes=[
            NodeGene(0, 'input'),
            NodeGene(1, 'input'),
            NodeGene(2, 1),
            NodeGene(3, 1),
            NodeGene(4, 'output'),
            NodeGene(5, 'output')
        ],
        edges=[
            EdgeGene(0, 0, 2, 0.7),
            EdgeGene(1, 1, 2, 0.2),
            EdgeGene(2, 0, 3, 0.5),
            EdgeGene(3, 1, 3, 0.1),
            EdgeGene(4, 2, 4, 0.3),
            EdgeGene(5, 2, 5, 0.4),
            EdgeGene(6, 3, 4, 0.8),
            EdgeGene(7, 3, 5, 0.9),
        ]
     )

C0.show()

# %%
c1 = Chromosome(id=1,inputs=2, hidden=3, outputs=3) #each run give different random net
c1.show()
